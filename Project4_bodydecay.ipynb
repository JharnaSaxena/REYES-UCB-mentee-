# %% [markdown]
# **Project #3**

# %%
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# %% [markdown]
# If we want to save our data to google drive, we have to connect our Python notebook to our google drive account! Running this will ask us to confirm that we want this notebook to be able to access drive. This will also make a folder called 'Python4Physics' in your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p "/content/drive/My Drive/Python4Physics"
filepath="drive/My Drive/Python4Physics/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Make sure you've created a copy of this notebook and the provided data file 'pBs_2body_decay.txt' in your Python4Physics folder.

# %%
# Let's get our data!
filename = 'pBs_2body_decay.txt'
d = np.loadtxt('/content/drive/My Drive/Python4Physics/pBs_2body_decay.txt')
####const_data = np.loadtxt('/content/drive/My Drive/Python4Physics/const_data.txt')
print("q0s = ", d[0:10])
print("type(q0s) = ", type(d))
print("shape(q0s) = ", np.shape(d))
print(d)

# These q0s are our momentum measurements
# Out:
# q0s =  [0.7338822  0.73414999 0.73213688 0.73275698 0.73319379 0.73484167
#  0.73355556 0.73283873 0.73216609 0.73458736]
# type(q0s) =  <class 'numpy.ndarray'>
# shape(q0s) =  (1000,)
# [0.7338822  0.73414999 0.73213688 0.73275698 0.73319379 0.73484167
#  0.73355556 0.73283873 0.73216609 0.73458736 0.73513384 0.73571701
#  0.73409012 0.73265256 0.7317403  0.73192565 0.73246459 0.73712389
#  0.73135611 0.73470297 0.73606284 0.73108794 0.73234649 0.73300034
#  0.73363903 0.72991719 0.73337303 0.7321668  0.73272392 0.73309046
#  0.73113086 0.73332097 0.73367737 0.73500344 0.73187349 0.73377991
#  0.73454556 0.73241032 0.73508295 0.73056094 0.73590097 0.73357675
#  0.73269356 0.73452724 0.73468794 0.73139302 0.7329468  0.73433313
#  0.7301741  0.73497367 0.73280959 0.73287839 0.73018759 0.73344139
#  0.73268997 0.73380152 0.73138749 0.73251917 0.73189188 0.73339298
#  0.73220079 0.73315523 0.73451673 0.73139657 0.73153275 0.73314695
#  0.73407499 0.7355656  0.73414651 0.73577887 0.73398312 0.73276927
#  0.7326078  0.73194026 0.73184785 0.7345162  0.73218731 0.73434321
#  0.73374259 0.73187897 0.73295203 0.73469302 0.73013997 0.73198223
#  0.7338368  0.73337765 0.73301089 0.73247763 0.73048796 0.73279923
#  0.7361627  0.7321555  0.73223405 0.72859879 0.7326431  0.73447669
#  0.73545967 0.73353511 0.73072857 0.73477781 0.73317038 0.73393934
#  0.73271687 0.73172436 0.73120849 0.73350489 0.73109737 0.73220509
#  0.73460859 0.73243514 0.73049771 0.7338063  0.73304302 0.73213889
#  0.73604145 0.73012768 0.73306694 0.73438303 0.73341659 0.73458668
#  0.73320682 0.73472321 0.73448716 0.73359712 0.73518203 0.7337757
#  0.73105806 0.73549707 0.73169582 0.73410733 0.73009269 0.73616735
#  0.73464027 0.73181035 0.73425618 0.72934418 0.73632048 0.73380467
#  0.73299632 0.73103944 0.73300143 0.7327057  0.73466758 0.73353879
#  0.73007152 0.73530392 0.73497225 0.73376023 0.73393986 0.73632522
#  0.73182439 0.73386028 0.73498786 0.73322353 0.73457998 0.73326994
#  0.73206667 0.73272706 0.7319511  0.73408856 0.73533556 0.73292831
#  0.73428667 0.73009462 0.73470559 0.72943186 0.73526801 0.73464477
#  0.73405654 0.73346151 0.73103554 0.73353358 0.73021127 0.73092488
#  0.73259801 0.7340329  0.73409469 0.73340496 0.733278   0.7318795
#  0.73008713 0.7312059  0.73583695 0.73435047 0.73231069 0.73357277
#  0.73492108 0.73331342 0.73273318 0.73157123 0.73521194 0.73060941
#  0.73305422 0.73392535 0.73132553 0.73600348 0.731705   0.73297316
#  0.73450881 0.73256617 0.73386239 0.73178461 0.73559862 0.73165861
#  0.73478557 0.7336575  0.73489538 0.73161492 0.73356875 0.73340258
#  0.73263223 0.73082317 0.73474089 0.73539007 0.73371127 0.73352628
#  0.73009778 0.73402765 0.7339779  0.73472165 0.73140423 0.73485026
#  0.73640759 0.73589802 0.73183026 0.73438454 0.73089128 0.73288993
#  0.73518338 0.73543439 0.73810418 0.7324432 ]

# %%
# let us make a figure using the axes class
# first, we create a new figure; we will also learn about multi-line comments created with ''' or """
# Matplotlib user guide: https://matplotlib.org/stable/users/index.html
fig = plt.figure()
''' next, we create a axes canvas.  The 4 numbers represent
    ax = plt.axes([x0, y0, dx, dy])
    - x0: width from left to start canvas (in units of 0 - 1)
    - y0: height from bottome to start canvas
    - dx: width of canvas - NOTE, x0 + dx <= 1
    - dy: height of canvas - NOTE, y0 + dy <= 1
'''

# your code here
#my code here
ax=plt.axes([0.3,0.3,0.9,0.9])

''' Now let us plot the histogram
    - Nbins  : the number of bins to use
    - alpha  : a parameter taking the value [0, 1] that controls opacity
    - ;      : the semi-colon at the end prevents the function from printing
               values of the histogram - try removing it
    - density: if True, it will normalize so that int(hist) = 1

'''

# your code here
#my code
d=np.random.normal(0,1,1000)
ax.hist(d, bins=15,alpha=0.5,density=True);
# let us make some axis labels
ax.set_ylabel(r'count', fontsize=20);
ax.set_xlabel(r'momentum, $p_B$', fontsize=20);

# %%
# let us make a figure using the axes class
# first, we create a new figure; we will also learn about multi-line comments created with ''' or """
# Matplotlib user guide: https://matplotlib.org/stable/users/index.html
fig = plt.figure()
''' next, we create a axes canvas.  The 4 numbers represent
    ax = plt.axes([x0, y0, dx, dy])
    - x0: width from left to start canvas (in units of 0 - 1)
    - y0: height from bottome to start canvas
    - dx: width of canvas - NOTE, x0 + dx <= 1
    - dy: height of canvas - NOTE, y0 + dy <= 1
'''

# your code here
#my code here
ax=plt.axes([0.1, 0.2, 0.2, 0.7])

''' Now let us plot the histogram
    - Nbins  : the number of bins to use
    - alpha  : a parameter taking the value [0, 1] that controls opacity
    - ;      : the semi-colon at the end prevents the function from printing
               values of the histogram - try removing it
    - density: if True, it will normalize so that int(hist) = 1

'''

# your code here
#my code
d=np.random.normal(0,1,1000)
ax.hist(d, bins=15,alpha=0.5,density=True);
# let us make some axis labels
ax.set_ylabel(r'count', fontsize=20);
ax.set_xlabel(r'momentum, $p_B$', fontsize=20);

# plot the mean value (hint: https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html)
mea=d.mean()
ax.axvline(mea,color="pink",linestyle=":",label="MEAN")
# plot the standard deviation
st=d.std()
ax.axvline(mea-st,color="blue",linestyle="-",label="-1 Std Dev")
ax.axvline(mea+st,color="blue",linestyle="-",label="+1 Std Dev")
# plot the median
# your code here
media=np.median(d)
ax.axvline(media, color="green",linestyle="--", label="Median")

# %% [markdown]
# Is the data Gaussian? It should be! If the data is "normally distributed", it will have the shape of a Gaussian -- see https://en.wikipedia.org/wiki/Normal_distribution.
#
# Let's check. You can just run this cell.

# %%
# let us make a figure using the axes class
# first, we create a new figure; we will also learn about multi-line comments created with ''' or """
# Matplotlib user guide: https://matplotlib.org/stable/users/index.html
fig = plt.figure()
''' next, we create a axes canvas.  The 4 numbers represent
    ax = plt.axes([x0, y0, dx, dy])
    - x0: width from left to start canvas (in units of 0 - 1)
    - y0: height from bottome to start canvas
    - dx: width of canvas - NOTE, x0 + dx <= 1
    - dy: height of canvas - NOTE, y0 + dy <= 1
'''

# your code here
#my code here
ax=plt.axes([0.1, 0.2, 0.2, 0.7])

''' Now let us plot the histogram
    - Nbins  : the number of bins to use
    - alpha  : a parameter taking the value [0, 1] that controls opacity
    - ;      : the semi-colon at the end prevents the function from printing
               values of the histogram - try removing it
    - density: if True, it will normalize so that int(hist) = 1

'''

# your code here
#my code
d=np.random.normal(0,1,1000)
ax.hist(d, bins=15,alpha=0.5,density=True);
# let us make some axis labels
ax.set_ylabel(r'count', fontsize=20);
ax.set_xlabel(r'momentum, $p_B$', fontsize=20);

# plot the mean value (hint: https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html)
mea=d.mean()
ax.axvline(mea,color="pink",linestyle=":",label="MEAN")
# plot the standard deviation
st=d.std()
ax.axvline(mea-st,color="blue",linestyle="-",label="-1 Std Dev")
ax.axvline(mea+st,color="blue",linestyle="-",label="+1 Std Dev")
# plot the median
# your code here
media=np.median(d)
ax.axvline(media, color="green",linestyle="--", label="Median")


# plot Gaussian [normal] distrubution
''' If the data is "normally distributed", it will have the shape of a Gaussian
    see https://en.wikipedia.org/wiki/Normal_distribution

    prob(x) = Norm * exp( -(x - x_mean) / 2 / sigma**2)

    solve for Norm by

    1 = integral[-inf, inf] dx prob(x)

    Norm = 1 / sqrt(2 * pi * sigma**2)
'''
# create linespace
n_plot = 10000
x_min  = min(d)
x_max  = max(d)
x_plot = np.arange(x_min, x_max + (x_max-x_min)/n_plot, 1/n_plot)

def mom_dist(x, x_mean, x_sigma):
  Norm = 1 / np.sqrt( (2 * np.pi * x_sigma**2) )
  prob = Norm * np.exp( -(x - x_mean)**2 / 2 / x_sigma**2)

  return prob

gauss = mom_dist(x_plot, d.mean(), d.std())
ax.plot(x_plot, gauss, color='magenta', label='Gaussian approximation')

# plot our legend
ax.legend(loc=2)

# %% [markdown]
# Now we want to calculate and plot the unknown mass m_c.
# Remember, the necessary equations and variables are in the slides!

# %%
# Define missing_mass function

def missing_mass(mA, mB, d):
  # your code here
    energy=np.sqrt(d**2 + mB**2)
    mcsquare=(mA - energy)**2 - d**2
    m=np.sqrt(mcsquare)
    return m

# %%
# Plot the mass distribution histogram like we did above
mA=5.755128732
mB=6.289387273
m=missing_mass(mA, mB, d)
# your code here
f=plt.figure()
axq=plt.axes([0.1, 0.2, 0.8, 0.7])
axq.hist(m,bins=15,alpha=0.5,label="Missing mass")
axq.set_xlabel("Mass of Invisible Particle", fontsize=12)
axq.set_ylabel("Count", fontsize=12)
axq.legend()
# Out:
# /tmp/ipython-input-1741946164.py:7: RuntimeWarning: invalid value encountered in sqrt
#   m=np.sqrt(mcsquare)
